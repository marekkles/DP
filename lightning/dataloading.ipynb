# %%
import pytorch_lightning as pl

# %%
from dataset.iris_dataset import *

# %%
root_dir = "../../Datasets/"
root_dir_ver = "../../Datasets/iris_verification_iitd_01_01"
subsets = [
    #"train_iris_nd_crosssensor_2013", 
    "train_iris_casia_v4",
    #"train_iris_inno_a1",
    #"train_iris_nd_0405",
    #"train_iris_utris_v1"
]

# %%
ds = IrisDataset(root_dir, subsets)
ds_2 = IrisVerificationDataset(root_dir_ver)

# %%
ds.num_classes
# Out:
# 1600

# %%
ds_2.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-8323b2811be5> in <module>
# ----> 1 ds_2.size
#
# AttributeError: 'IrisVerificationDataset' object has no attribute 'size'

# %%
img = ds[len(ds)-1]

# %%
import matplotlib.pyplot as plt
plt.imshow(img[0][0])

# %%
import time
time.time_ns()//1_000_000_000
# Out:
# 1645969702
