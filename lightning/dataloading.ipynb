# %%
import pytorch_lightning as pl

# %%
from dataset.iris_dataset import *

# %%
root_dir = "../../Datasets/"
root_dir_ver = "../../Datasets/iris_verification_iitd_01_01"
subsets = [
    "train_iris_nd_crosssensor_2013", 
    "train_iris_casia_v4",
    "train_iris_inno_a1",
    "train_iris_nd_0405",
    "train_iris_utris_v1"
]

# %%
ds = IrisDataset(root_dir, subsets,autocrop=True, unwrap=True)
ds_2 = IrisVerificationDataset(root_dir_ver,autocrop=True,unwrap=True)

# %%
ds.num_classes
# Out:
# 42877

# %%
len(ds_2)
# Out:
# 2240

# %%
ds_2.size
# Out:
# 2240

# %%
img = ds_2[0]

# %%
# %matplotlib inline
# produce vector inline graphics
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')
import matplotlib.pyplot as plt
plt.imshow(img[0][0], cmap='gray')

# %%
import time
time.time_ns()//1_000_000_000
# Out:
# 1647620898
