# %%
import os
import csv
import matplotlib.pyplot as plt
from PIL import Image,ImageDraw
from torchvision.datasets.vision import *
import torch
import copy

# %%
datasets0 = [
    'iris_verification_iitd_01_01',
    'iris_verification_inno_a1_01_03',
    'iris_verification_NDCSI2013_01_05'
]
datasets = [
    'train_iris_casia_v4',
    'train_iris_inno_a1',
    'train_iris_nd_0405',
    'train_iris_nd_crosssensor_2013',
    'train_iris_utris_v1'
]

root = os.path.join('..', 'Datasets')

datasets = [os.path.join(root, d) for d in [datasets[0], datasets[3] ] ]

dataset_id = 0

dataset_dir = os.path.join(root, datasets[dataset_id])
annotations_path = os.path.join(dataset_dir, 'annotations.csv')
with open(annotations_path, newline='') as csvfile:
    annotations = csv.reader(csvfile, delimiter=',', quotechar='"')
    annotations_list = list(annotations)

# %%
dataset_dir
# Out:
# '../Datasets/../Datasets/train_iris_casia_v4'

# %%
dataset_dir
# Out:
# '../Datasets/../Datasets/train_iris_casia_v4'

# %%
datasets
# Out:
# ['../Datasets/train_iris_casia_v4',
#  '../Datasets/train_iris_nd_crosssensor_2013']

# %%
from datasets import *

# %%
ds = IrisDataset(datasets, mode="classification", image_set="train")

# %%
ds.num_classes
# Out:
# 2540

# %%
len(ds.subjects)
# Out:
# 117858

# %%
len(ds)
# Out:
# 88395

# %%
len(ds.picked_subjects)/len(ds.subjects)
# Out:
# 0.1499056010069226

# %%
len(ds)
# Out:
# 2382

# %%
ds.num_classes
# Out:
# 1600

# %%
for i in range(4):
    ind = i*30
    img, target = ds[ind]
    ax1 = plt.subplot(2,4,(i*2+1))
    ax1.imshow(img, 'gray')
    if type(target) == int:
        print(target, ds.id_to_subject_dict[target])
    else:
        ax1 = plt.subplot(2,4,(i*2+2))
        ax1.imshow(target)
# Out:
# 1 iris_casia_v4_383_2
# 21 iris_casia_v4_974_2
# 41 iris_casia_v4_553_1
# 62 iris_casia_v4_328_2

# %%
ids = {}
for i, j in ds:
    if not j in ids:
        ids[j] = 0
    ids[j] += 1
print(max(ids))
# Out:
# 1598

# %%
header = annotations_list[0]
params = annotations_list[2]

# %%
print( '\n'.join("{:<20}: {:<28}".format(*k) for k in zip(header, params) ) )
# Out:
#                     : 1
# YOB                 : 1978
# added_by            : dthomas4
# by_user             : sbaker3
# collectionid        : nd1C00013
# confidence          : 0.9999563097953796
# contacts            : No
# contacts_cosmetic   : No
# contacts_texture    : No
# contacts_toric      : No
# date                : 2008-04-01 00:00:00
# date_added          : 2008-08-12 18:12:10
# db_id               : iris_nd_crosssensor_2013
# detection_info      : iface 3.9.0
# environmentid       : nd1E00074
# eye_color           : Brown
# eye_side            : 1
# fold                : 1
# fstate              : ok
# gender              : 2
# glass_status        : 1
# groupid             : 1
# illuminantid        : nd1I00017,stdI00002
# illuminantid1       : nd1I00012
# image_container_path: image_containers/images_iris_nd_crosssensor_2013_00.h5
# image_id            : 2008_092_021_L_1_4R-lg2200.tiff
# motion              : Still
# pos_x               : 387.4176330566406
# pos_y               : 205.3508758544922
# pose                : 0
# quality             : 69.88932291666667
# r_priority          : 1
# race                : 7
# radius_0            : 50.31953430175781
# radius_1            : 115.03082275390625
# rank                : 0
# sensor_name         : LG2200
# sensorid            : nd1N00006
# shot                : 2
# stageid             : nd1T00014
# state               : ok
# subject_id          : nd1S05368
# treatment           : No
# validity            : 1
# weather             : Inside

# %%
import pandas as pd

# %%
df = pd.read_csv( annotations_path)

# %%
df.groupby(['subject_id','eye_side']).count()
# Out:
#                      Unnamed: 0  YOB  added_by  by_user  collectionid  \
# subject_id eye_side
# nd1S02463  1                315  315       315      315           315
#            2                323  323       323      323           323
# nd1S04233  2                339  339       339      339           337
# nd1S04252  1                 36   36        36       36            36
# nd1S04261  2                215  215       215      215           215
# ...                         ...  ...       ...      ...           ...
# nd1S06265  2                 39   39        39       39            39
# nd1S06266  2                 30   30        30       30            30
# nd1S06267  1                 29   29        29       29            29
# nd1S06269  1                 30   30        30       30            30
#            2                 30   30        30       30            30
#
#                      confidence  contacts  contacts_cosmetic  \
# subject_id eye_side
# nd1S02463  1                315       315                315
#            2                323       323                323
# nd1S04233  2                339       339                339
# nd1S04252  1                 36        36                 36
# nd1S04261  2                215       215                215
# ...                         ...       ...                ...
# nd1S06265  2                 39        39                 39
# nd1S06266  2                 30        30                 30
# nd1S06267  1                 29        29                 29
# nd1S06269  1                 30        30                 30
#            2                 30        30                 30
#
#                      contacts_texture  contacts_toric  ...  radius_1  rank  \
# subject_id eye_side                                    ...
# nd1S02463  1                      315             315  ...       315   195
#            2                      323             323  ...       323   206
# nd1S04233  2                      339             339  ...       339   219
# nd1S04252  1                       36              36  ...        36    36
# nd1S04261  2                      215             215  ...       215   125
# ...                               ...             ...  ...       ...   ...
# nd1S06265  2                       39              39  ...        39     0
# nd1S06266  2                       30              30  ...        30     0
# nd1S06267  1                       29              29  ...        29     0
# nd1S06269  1                       30              30  ...        30     0
#            2                       30              30  ...        30     0
#
#                      sensor_name  sensorid  shot  stageid  state  treatment  \
# subject_id eye_side
# nd1S02463  1                 315       315   180      315    315        195
#            2                 323       323   191      323    323        206
# nd1S04233  2                 339       339   219      339    339        219
# nd1S04252  1                  36        36    36       36     36         36
# nd1S04261  2                 215       215   125      215    215        125
# ...                          ...       ...   ...      ...    ...        ...
# nd1S06265  2                  39        39     0       39     39          0
# nd1S06266  2                  30        30     0       30     30          0
# nd1S06267  1                  29        29     0       29     29          0
# nd1S06269  1                  30        30     0       30     30          0
#            2                  30        30     0       30     30          0
#
#                      validity  weather
# subject_id eye_side
# nd1S02463  1              315      315
#            2              323      323
# nd1S04233  2              339      339
# nd1S04252  1               36       36
# nd1S04261  2              215      215
# ...                       ...      ...
# nd1S06265  2               39       39
# nd1S06266  2               30       30
# nd1S06267  1               29       29
# nd1S06269  1               30       30
#            2               30       30
#
# [940 rows x 43 columns]

# %%
df[df['subject_id'] == 'nd1S02463']
# Out:
#         Unnamed: 0   YOB  added_by   by_user collectionid  confidence  \
# 308            393  1956  dthomas4     flynn    nd1C00013    0.999991
# 309            394  1956  dthomas4     flynn    nd1C00013    0.999996
# 310            395  1956  dthomas4     flynn    nd1C00013    0.999993
# 311            396  1956  dthomas4     flynn    nd1C00013    0.999974
# 312            397  1956  dthomas4     flynn    nd1C00013    0.999991
# ...            ...   ...       ...       ...          ...         ...
# 101013      145601  1956     chelm  dwright2    nd1C00042    0.999978
# 101014      145602  1956     chelm  dwright2    nd1C00042    0.999922
# 101015      145603  1956     chelm  dwright2    nd1C00042    0.999981
# 101016      145604  1956     chelm  dwright2    nd1C00042    0.999952
# 101017      145605  1956     chelm  dwright2    nd1C00042    0.999984
#
#        contacts contacts_cosmetic contacts_texture contacts_toric  ... rank  \
# 308          No                No               No             No  ...  0.0
# 309          No                No               No             No  ...  0.0
# 310          No                No               No             No  ...  0.0
# 311          No                No               No             No  ...  0.0
# 312          No                No               No             No  ...  0.0
# ...         ...               ...              ...            ...  ...  ...
# 101013       No                No               No             No  ...  NaN
# 101014       No                No               No             No  ...  NaN
# 101015       No                No               No             No  ...  NaN
# 101016       No                No               No             No  ...  NaN
# 101017       No                No               No             No  ...  NaN
#
#        sensor_name   sensorid shot    stageid state  subject_id  treatment  \
# 308         LG2200  nd1N00006  1.0  nd1T00014    ok   nd1S02463         No
# 309         LG2200  nd1N00006  1.0  nd1T00014    ok   nd1S02463         No
# 310         LG2200  nd1N00006  1.0  nd1T00014    ok   nd1S02463         No
# 311         LG2200  nd1N00006  2.0  nd1T00014    ok   nd1S02463         No
# 312         LG2200  nd1N00006  2.0  nd1T00014    ok   nd1S02463         No
# ...            ...        ...  ...        ...   ...         ...        ...
# 101013      LG4000  nd1N00020  NaN  nd1T00016    ok   nd1S02463        NaN
# 101014      LG4000  nd1N00020  NaN  nd1T00016    ok   nd1S02463        NaN
# 101015      LG4000  nd1N00020  NaN  nd1T00016    ok   nd1S02463        NaN
# 101016      LG4000  nd1N00020  NaN  nd1T00016    ok   nd1S02463        NaN
# 101017      LG4000  nd1N00020  NaN  nd1T00016    ok   nd1S02463        NaN
#
#        validity  weather
# 308           1   Inside
# 309           1   Inside
# 310           1   Inside
# 311           1   Inside
# 312           1   Inside
# ...         ...      ...
# 101013        1   Inside
# 101014        1   Inside
# 101015        1   Inside
# 101016        1   Inside
# 101017        1   Inside
#
# [638 rows x 45 columns]

# %%
df['validity'].max()
# Out:
# 1
